# %%
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout, ZeroPadding2D, UpSampling2D
from tensorflow.keras.layers import Conv1D,MaxPooling1D,Conv1DTranspose,AveragePooling1D,GlobalMaxPool1D,GlobalAveragePooling1D
from tensorflow.keras.layers import Conv2D,MaxPool2D,Conv2DTranspose,AveragePooling2D,GlobalMaxPool2D,GlobalAveragePooling2D
from tensorflow.keras.layers import Conv3D,MaxPooling3D,Conv3DTranspose,AveragePooling3D,GlobalMaxPool3D,GlobalAveragePooling3D
from tensorflow.keras.layers import Dense,Flatten,Dropout,Concatenate,Layer,BatchNormalization,Input,Add,Activation,Average

from keras.models import Model, Sequential
from keras import backend as K
from keras.optimizers import Adam, RMSprop
from keras.utils import plot_model
from keras.initializers import RandomNormal

# %%
glorot_normal = RandomNormal(stddev=0.01)

input2D_1 = Input(shape=(512,512,3))
conv2D_11 = Conv2D(32 , kernel_size=(3,3),strides=(2,2),padding = 'same',use_bias=True,kernel_initializer= glorot_normal)(input2D_1)
batchnormalization_7 = BatchNormalization()(conv2D_11)
conv2D_45 = Conv2D(64 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True,kernel_initializer= glorot_normal)(batchnormalization_7)
batchnormalization_25 = BatchNormalization()(conv2D_45)
activation_19 = Activation(activation='relu')(batchnormalization_25)
conv2D_1 = Conv2D(128 , kernel_size=(3,3),strides=(1,1),padding = 'same')(activation_19)
conv2D_9 = Conv2D(1 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(activation_19)
conv2D_23 = Conv2D(128 , kernel_size=(1,1),strides=(2,2),padding = 'same',use_bias=True)(activation_19)
batchnormalization_1 = BatchNormalization()(conv2D_1)
transpoze2D_3 = Conv2DTranspose(1 , kernel_size=(2,2),strides=(2,2),padding = 'same')(conv2D_9)
conv2D_7 = Conv2D(128 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(batchnormalization_1)
batchnormalization_16 = BatchNormalization()(conv2D_7)
activation_1 = Activation(activation='relu')(batchnormalization_16)
conv2D_24 = Conv2D(1 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(activation_1)
maxpool2D_1 = MaxPool2D(pool_size=(3,3),strides=(2,2),padding = 'same')(activation_1)
transpoze2D_4 = Conv2DTranspose(1 , kernel_size=(2,2),strides=(2,2),padding = 'same')(conv2D_24)
add_1 = Add()([conv2D_23,maxpool2D_1])
conv2D_34 = Conv2D(256 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(maxpool2D_1)
conv2D_41 = Conv2D(256 , kernel_size=(1,1),strides=(2,2),padding = 'same',use_bias=True)(maxpool2D_1)
activation_16 = Activation(activation='relu')(add_1)
conv2D_51 = Conv2D(256 , kernel_size=(1,1),strides=(2,2),padding = 'same',use_bias=True)(add_1)
conv2D_6 = Conv2D(512 , kernel_size=(1,1),strides=(2,2),padding = 'same')(conv2D_41)
conv2D_39 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_16)
batchnormalization_14 = BatchNormalization()(conv2D_39)
activation_17 = Activation(activation='relu')(batchnormalization_14)
conv2D_37 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_17)
batchnormalization_5 = BatchNormalization()(conv2D_37)
average_3 = Average()([batchnormalization_5,conv2D_34])
activation_14 = Activation(activation='relu')(average_3)
conv2D_36 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_14)
batchnormalization_12 = BatchNormalization()(conv2D_36)
activation_15 = Activation(activation='relu')(batchnormalization_12)
conv2D_25 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_15)
batchnormalization_3 = BatchNormalization()(conv2D_25)
average_2 = Average()([batchnormalization_3,conv2D_34])
conv2D_43 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(average_2)
maxpool2D_2 = MaxPool2D(pool_size=(3,3),strides=(2,2),padding = 'same')(average_2)
transpoze2D_9 = Conv2DTranspose(16 , kernel_size=(4,4),strides=(2,2),padding = 'same')(conv2D_43)
add_2 = Add()([conv2D_51,maxpool2D_2])
add_4 = Add()([conv2D_41,maxpool2D_2])
conv2D_19 = Conv2D(1 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_9)
conv2D_4 = Conv2D(512 , kernel_size=(1,1),strides=(2,2),padding = 'same',use_bias=True)(add_2)
conv2D_8 = Conv2D(512 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(add_4)
transpoze2D_10 = Conv2DTranspose(1 , kernel_size=(4,4),strides=(2,2),padding = 'same')(conv2D_19)
activation_18 = Activation(activation='relu')(add_2)
conv2D_38 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_18)
batchnormalization_18 = BatchNormalization()(conv2D_38)
activation_13 = Activation(activation='relu')(batchnormalization_18)
conv2D_33 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_13)
batchnormalization_26 = BatchNormalization()(conv2D_33)
average_11 = Average()([batchnormalization_26,conv2D_8])
activation_9 = Activation(activation='relu')(average_11)
conv2D_32 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_9)
batchnormalization_20 = BatchNormalization()(conv2D_32)
activation_23 = Activation(activation='relu')(batchnormalization_20)
conv2D_20 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_23)
batchnormalization_24 = BatchNormalization()(conv2D_20)
average_10 = Average()([batchnormalization_24,conv2D_8])
activation_7 = Activation(activation='relu')(average_10)
conv2D_35 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_7)
batchnormalization_22 = BatchNormalization()(conv2D_35)
activation_8 = Activation(activation='relu')(batchnormalization_22)
conv2D_30 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_8)
batchnormalization_2 = BatchNormalization()(conv2D_30)
average_9 = Average()([batchnormalization_2,conv2D_8])
conv2D_49 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(average_9)
maxpool2D_3 = MaxPool2D(pool_size=(3,3),strides=(2,2),padding = 'same')(average_9)
transpoze2D_15 = Conv2DTranspose(16 , kernel_size=(8,8),strides=(2,2),padding = 'same')(conv2D_49)
add_3 = Add()([conv2D_4,maxpool2D_3])
add_5 = Add()([conv2D_6,maxpool2D_3])
conv2D_5 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_15)
activation_22 = Activation(activation='relu')(add_3)
conv2D_14 = Conv2D(512 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(add_3)
conv2D_10 = Conv2D(512 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(add_5)
transpoze2D_2 = Conv2DTranspose(16 , kernel_size=(8,8),strides=(2,2),padding = 'same')(conv2D_5)
conv2D_48 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_22)
conv2D_46 = Conv2D(1 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_2)
batchnormalization_15 = BatchNormalization()(conv2D_48)
transpoze2D_8 = Conv2DTranspose(1 , kernel_size=(8,8),strides=(2,2),padding = 'same')(conv2D_46)
activation_24 = Activation(activation='relu')(batchnormalization_15)
conv2D_26 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_24)
batchnormalization_23 = BatchNormalization()(conv2D_26)
average_5 = Average()([batchnormalization_23,conv2D_10])
activation_20 = Activation(activation='relu')(average_5)
conv2D_28 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_20)
batchnormalization_21 = BatchNormalization()(conv2D_28)
activation_21 = Activation(activation='relu')(batchnormalization_21)
conv2D_22 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_21)
batchnormalization_13 = BatchNormalization()(conv2D_22)
average_4 = Average()([batchnormalization_13,conv2D_10])
activation_3 = Activation(activation='relu')(average_4)
conv2D_21 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_3)
batchnormalization_9 = BatchNormalization()(conv2D_21)
activation_4 = Activation(activation='relu')(batchnormalization_9)
conv2D_13 = Conv2D(512 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_4)
batchnormalization_11 = BatchNormalization()(conv2D_13)
average_1 = Average()([batchnormalization_11,conv2D_10])
add_6 = Add()([average_1,conv2D_14])
conv2D_16 = Conv2D(256 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(average_1)
conv2D_40 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(average_1)
activation_5 = Activation(activation='relu')(add_6)
transpoze2D_12 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_40)
conv2D_29 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_5)
conv2D_2 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_12)
batchnormalization_19 = BatchNormalization()(conv2D_29)
transpoze2D_6 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_2)
activation_6 = Activation(activation='relu')(batchnormalization_19)
conv2D_42 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_6)
conv2D_18 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_6)
transpoze2D_13 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_42)
batchnormalization_4 = BatchNormalization()(conv2D_18)
conv2D_47 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_13)
average_8 = Average()([batchnormalization_4,conv2D_16])
transpoze2D_7 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_47)
activation_11 = Activation(activation='relu')(average_8)
conv2D_27 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_11)
batchnormalization_17 = BatchNormalization()(conv2D_27)
activation_12 = Activation(activation='relu')(batchnormalization_17)
conv2D_3 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_12)
batchnormalization_10 = BatchNormalization()(conv2D_3)
average_7 = Average()([batchnormalization_10,conv2D_16])
activation_10 = Activation(activation='relu')(average_7)
conv2D_15 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_10)
batchnormalization_6 = BatchNormalization()(conv2D_15)
activation_2 = Activation(activation='relu')(batchnormalization_6)
conv2D_31 = Conv2D(256 , kernel_size=(3,3),strides=(1,1),padding = 'same',use_bias=True)(activation_2)
batchnormalization_8 = BatchNormalization()(conv2D_31)
average_6 = Average()([batchnormalization_8,conv2D_16])
conv2D_44 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(average_6)
transpoze2D_5 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_44)
conv2D_12 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_5)
transpoze2D_11 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_12)
conv2D_17 = Conv2D(16 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_11)
transpoze2D_14 = Conv2DTranspose(16 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_17)
conv2D_50 = Conv2D(1 , kernel_size=(1,1),strides=(1,1),padding = 'same',use_bias=True)(transpoze2D_14)
transpoze2D_1 = Conv2DTranspose(1 , kernel_size=(16,16),strides=(2,2),padding = 'same')(conv2D_50)
concatenate_1 = Concatenate()([transpoze2D_1,transpoze2D_3,transpoze2D_4,transpoze2D_7,transpoze2D_8,transpoze2D_10])




model = Model(inputs =input2D_1 , outputs=concatenate_1)
# Out:
# H:\download\anaconda3_envs\generativeTensorflowCudaV2\lib\site-packages\keras\initializers\initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  18496       ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
# ...

# %%
plot_model(model, show_shapes=True, to_file='output_layer_ends_with_dim512x512x21_modelDoesNOTwork.png')
